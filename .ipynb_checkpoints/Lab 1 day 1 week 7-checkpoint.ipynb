# %%
import pandas as pd
import numpy as np

# Replace 'path_to_file' with the actual path to your CSV file
file_path = 'learningSet.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to verify that it was read correctly
df.head()
# Out:
# /var/folders/pf/nfj1603d1fjc2xkhkrlls95m0000gn/T/ipykernel_32650/2004329379.py:8: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0     8901     GRI      0    IL  61081                    3712      0
# 1     9401     BOA      1    CA  91326                    5202      0
# 2     9001     AMH      1    NC  27017                       0      0
# 3     8701     BRY      0    CA  95953                    2801      0
# 4     8601              0    FL  33176                    2001      0
#
#   RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A MDMAUD_R  MDMAUD_F  \
# 0           ...      0.0        0      L      4      E        X         X
# 1           ...      0.0        0      L      2      G        X         X
# 2           ...      0.0        1      L      4      E        X         X
# ...

# %%
# Check for null values in all columns
null_values = df.isnull().sum()
print("Null values in each column:")
print(null_values)

# Create a new empty list called drop_list
drop_list = []

# Exclude the following variables by looking at the definitions and append them to drop_list
drop_list.extend(['OSOURCE', 'ZIP'])

# Drop columns in drop_list
df = df.drop(columns=drop_list)

# Verify that the columns have been dropped
print("Columns dropped:", drop_list)
print("Remaining columns:")
print(df.columns)
# Out:
# Null values in each column:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2    132
# Length: 481, dtype: int64
# Columns dropped: ['OSOURCE', 'ZIP']
# Remaining columns:
# Index(['ODATEDW', 'TCODE', 'STATE', 'MAILCODE', 'PVASTATE', 'DOB', 'NOEXCH',
#        'RECINHSE', 'RECP3', 'RECPGVG',
#        ...
#        'TARGET_D', 'HPHONE_D', 'RFA_2R', 'RFA_2F', 'RFA_2A', 'MDMAUD_R',
#        'MDMAUD_F', 'MDMAUD_A', 'CLUSTER2', 'GEOCODE2'],
#       dtype='object', length=479)

# %%
# Calculate the percentage of missing values in each column
missing_percentage = (df.isnull().sum() / len(df)) * 100

# Filter out columns with missing values exceeding 50%
columns_with_over_50_percent_missing = missing_percentage[missing_percentage > 50]

# Display the identified columns
print("Columns with over 50% missing values:")
print(columns_with_over_50_percent_missing)
# Out:
# Columns with over 50% missing values:
# NUMCHLD     87.018404
# MBCRAFT     55.395548
# MBGARDEN    55.395548
# MBBOOKS     55.395548
# MBCOLECT    55.458433
#               ...
# RAMNT_20    91.732696
# RAMNT_21    90.029556
# RAMNT_22    78.123297
# RAMNT_23    91.763091
# RAMNT_24    81.409047
# Length: 62, dtype: float64

# %%
# Remove columns with over 50% missing values from the DataFrame
df = df.drop(columns=columns_with_over_50_percent_missing.index)

# Verify that the columns have been removed
print("Columns removed:")
print(columns_with_over_50_percent_missing.index)
print("Remaining columns:")
print(df.columns)
# Out:
# Columns removed:
# Index(['NUMCHLD', 'MBCRAFT', 'MBGARDEN', 'MBBOOKS', 'MBCOLECT', 'MAGFAML',
#        'MAGFEM', 'MAGMALE', 'PUBGARDN', 'PUBCULIN', 'PUBHLTH', 'PUBDOITY',
#        'PUBNEWFN', 'PUBPHOTO', 'PUBOPP', 'ADATE_15', 'ADATE_20', 'ADATE_23',
#        'RDATE_3', 'RDATE_4', 'RDATE_5', 'RDATE_6', 'RDATE_7', 'RDATE_8',
#        'RDATE_9', 'RDATE_10', 'RDATE_11', 'RDATE_12', 'RDATE_13', 'RDATE_14',
#        'RDATE_15', 'RDATE_16', 'RDATE_17', 'RDATE_18', 'RDATE_19', 'RDATE_20',
#        'RDATE_21', 'RDATE_22', 'RDATE_23', 'RDATE_24', 'RAMNT_3', 'RAMNT_4',
#        'RAMNT_5', 'RAMNT_6', 'RAMNT_7', 'RAMNT_8', 'RAMNT_9', 'RAMNT_10',
#        'RAMNT_11', 'RAMNT_12', 'RAMNT_13', 'RAMNT_14', 'RAMNT_15', 'RAMNT_16',
#        'RAMNT_17', 'RAMNT_18', 'RAMNT_19', 'RAMNT_20', 'RAMNT_21', 'RAMNT_22',
#        'RAMNT_23', 'RAMNT_24'],
#       dtype='object')
# Remaining columns:
# Index(['ODATEDW', 'TCODE', 'STATE', 'MAILCODE', 'PVASTATE', 'DOB', 'NOEXCH',
# ...

# %%
df['MAILCODE'] = df['MAILCODE'].apply(lambda x: x.replace(" ", "A"))

# %%
df = df.apply(lambda x: x.replace(" ", np.NaN))

# %%
Y = df[['TARGET_B', 'TARGET_D']]
Y
# Out:
#        TARGET_B  TARGET_D
# 0             0       0.0
# 1             0       0.0
# 2             0       0.0
# 3             0       0.0
# 4             0       0.0
# ...         ...       ...
# 95407         0       0.0
# 95408         0       0.0
# 95409         0       0.0
# 95410         1      18.0
# 95411         0       0.0
#
# [95412 rows x 2 columns]

# %%
numerical = df.select_dtypes(np.number)
numerical = numerical.drop(columns = ['TARGET_B', 'TARGET_D'])
numerical.head()
# Out:
#    ODATEDW  TCODE   DOB   AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  \
# 0     8901      0  3712  60.0     NaN      NaN    0         0       39
# 1     9401      1  5202  46.0     6.0      9.0   16         0       15
# 2     9001      1     0   NaN     3.0      1.0    2         0       20
# 3     8701      0  2801  70.0     1.0      4.0    2         0       23
# 4     8601      0  2001  78.0     3.0      2.0   60         1       28
#
#    VIETVETS  ...  LASTGIFT  LASTDATE  FISTDATE  NEXTDATE  TIMELAG    AVGGIFT  \
# 0        34  ...      10.0      9512      8911    9003.0      4.0   7.741935
# 1        55  ...      25.0      9512      9310    9504.0     18.0  15.666667
# 2        29  ...       5.0      9512      9001    9101.0     12.0   7.481481
# 3        14  ...      10.0      9512      8702    8711.0      9.0   6.812500
# 4         9  ...      15.0      9601      7903    8005.0     14.0   6.864865
#
#    CONTROLN  HPHONE_D  RFA_2F  CLUSTER2
# ...

# %%
categorical = df.select_dtypes(object)
categorical.head()

categorical.isna().sum()/len(categorical)
# Out:
# STATE       0.000000
# MAILCODE    0.000000
# PVASTATE    0.984719
# NOEXCH      0.000073
# RECINHSE    0.929747
#               ...
# RFA_2A      0.000000
# MDMAUD_R    0.000000
# MDMAUD_F    0.000000
# MDMAUD_A    0.000000
# GEOCODE2    0.003343
# Length: 72, dtype: float64

# %%
pd.DataFrame(categorical['STATE'].value_counts()).reset_index()
# Out:
#    STATE  count
# 0     CA  17343
# 1     FL   8376
# 2     TX   7535
# 3     IL   6420
# 4     MI   5654
# 5     NC   4160
# 6     WA   3577
# 7     GA   3403
# 8     IN   2980
# 9     WI   2795
# 10    MO   2712
# 11    TN   2492
# 12    AZ   2407
# 13    OR   2183
# 14    MN   2175
# 15    CO   2032
# 16    SC   1759
# 17    AL   1705
# 18    KY   1620
# 19    OK   1617
# 20    LA   1594
# 21    KS   1294
# 22    IA   1271
# 23    AR   1020
# 24    MS    986
# 25    NV    979
# 26    NM    877
# 27    NE    754
# 28    UT    569
# 29    ID    533
# 30    MT    527
# 31    HI    449
# 32    SD    301
# 33    WY    283
# 34    AK    282
# 35    ND    260
# 36    AP     81
# 37    NY     71
# 38    VA     55
# 39    OH     52
# 40    PA     38
# 41    MD     34
# 42    NJ     26
# 43    MA     25
# 44    CT     23
# 45    AA     18
# 46    AE     15
# 47    ME     11
# 48    NH      8
# 49    VT      7
# 50    RI      6
# 51    VI      5
# 52    WV      4
# 53    GU      4
# ...

# %%
df = pd.DataFrame(categorical['STATE'].value_counts()).reset_index()

df.columns = ['state', 'count']
other_states = list(df[df['count']<2500]['state'])
#other_states
def clean_state(x):
    if x in other_states:
        return 'other'
    else:
        return x
    
categorical['STATE'] = list(map(clean_state, categorical['STATE']))

# %%
categorical['STATE'].value_counts()
# Out:
# STATE
# other    30457
# CA       17343
# FL        8376
# TX        7535
# IL        6420
# MI        5654
# NC        4160
# WA        3577
# GA        3403
# IN        2980
# WI        2795
# MO        2712
# Name: count, dtype: int64

# %%
# Replace null values in the 'GENDER' column with 'F'
categorical['GENDER'] = categorical['GENDER'].fillna('F')

# Replace values other than 'M' and 'F' with 'other'
categorical['GENDER'] = categorical['GENDER'].apply(lambda x: 'other' if x not in ['M', 'F'] else x)

# Verify the value counts after the transformation
print(categorical['GENDER'].value_counts())
# Out:
# GENDER
# F        54234
# M        39094
# other     2084
# Name: count, dtype: int64
